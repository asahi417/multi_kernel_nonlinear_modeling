# %% [markdown]
# # Visualize main result
# - select best parameter: dictinary_th, alpha_dict
# - search eta0 to be same initial convergence

# %% [markdown]
# ### 1d

# %%
import numpy as np
from glob import glob
from itertools import product
from model import nonlinear_signal_1d as n_sig
from model import MultiKernelRegressionFBS01 as Regressor_fbs
from model import MultiKernelRegressionPDA01 as Regressor_pda
from model.util import plot_full, save_stats, realize_loop

order ="1"

re = np.load("./results/%sd/realize_100.npz" % order)
print(re["name"])

plot_full(re["error"], re["dictionary"], ["APFBS", "PDA"], save_path="./figure/%sd/" % order)
# Out:
# ['fbs_dict_1e-10_a_1e-08_eta_0.3' 'pda_dict_1e-10_a_1e-06_eta_0.3']

# %% [markdown]
# ### 2d

# %%
import numpy as np
from glob import glob
from itertools import product
from model import nonlinear_signal_2d as n_sig
from model import MultiKernelRegressionFBS01 as Regressor_fbs
from model import MultiKernelRegressionPDA01 as Regressor_pda
from model.util import plot_full, save_stats, realize_loop

order ="2"

re = np.load("./results/%sd/realize_100.npz" % order)
print(re["name"])

plot_full(re["error"], re["dictionary"], ["APFBS", "PDA"], save_path="./figure/%sd/" % order)
# Out:
# ['fbs_dict_1e-12_a_1e-12_eta_0.2' 'pda_dict_1e-12_a_1e-06_eta_0.2']
