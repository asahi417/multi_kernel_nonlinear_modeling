# %%
% matplotlib inline
from model import simulator

# %%
ls
# Out:
# model/                      test_notebooks/   train00_2d.ipynb
# signal_visualization.ipynb  train00_1d.ipynb  train_parameter_search.ipynb

# %%
simulator.plot_signal_1d()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-71c83779a6f2> in <module>()
# ----> 1 simulator.plot_signal_1d()
#
# AttributeError: module 'model.simulator' has no attribute 'plot_signal_1d'

# %%
plot_signal_2d()
