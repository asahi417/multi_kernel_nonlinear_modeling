# %%
% matplotlib inline
from matplotlib import pyplot as plt

# %%
import numpy as np
from itertools import product
from model import MultiKernelRegressorPDA as Regressor
from model import nonlinear_siganl_2d

# %%
def ma(target, window):
    return [np.mean(target[_s:_s+window]) for _s in range(len(target)-window)]

def plot_result(regressor):
    fig = plt.figure(0)
    plt.plot(regressor.r_dict_size)
    window = 100
    fig = plt.figure(1)
    plt.plot(ma(regressor.r_error, window))
    plt.yscale("log")
    plt.show()

# %%
size = 5000
noise_std = 0.01
x, y, y_noise = nonlinear_siganl_2d(size, noise_std)

# %%
a = np.arange(1, 10)
b = np.arange(-4, 2)

kernel_parameter = [i[0]*10.0**i[1] for i in product(a, b)]
eta0 = 0.3
dict_size = 20

# %%
dictionary_th = 10**-11
alpha_dict = 10**-7
alpha_element = alpha_dict*10**-1

regressor = Regressor(
    eta0=eta0,
    kernel_parameter=kernel_parameter,
    dictionary_th=dictionary_th,
    dict_size=dict_size,
    alpha_dict=alpha_dict,
    alpha_element=alpha_element
)
regressor.fit(x, y)
plot_result(regressor)
# Out:
# 100% (5000 of 5000) |#####################| Elapsed Time: 0:01:09 ETA:  0:00:00

# %%
dictionary_th = 10**-12
alpha_dict = 5*10**-7
alpha_element = alpha_dict*10**-1

regressor = Regressor(
    eta0=eta0,
    kernel_parameter=kernel_parameter,
    dictionary_th=dictionary_th,
    dict_size=dict_size,
    alpha_dict=alpha_dict,
    alpha_element=alpha_element
)
regressor.fit(x, y)
plot_result(regressor)
# Out:
#  99% (4999 of 5000) |#################### | Elapsed Time: 0:00:59 ETA:  0:00:00

# %%
dictionary_th = 10**-11
alpha_dict = 10**-8
alpha_element = alpha_dict*10**-1

regressor = Regressor(
    eta0=eta0,
    kernel_parameter=kernel_parameter,
    dictionary_th=dictionary_th,
    dict_size=dict_size,
    alpha_dict=alpha_dict,
    alpha_element=alpha_element
)
regressor.fit(x, y)
plot_result(regressor)
# Out:
#  99% (4999 of 5000) |#################### | Elapsed Time: 0:00:54 ETA:  0:00:00

# %%
dictionary_th = 10**-11
alpha_dict = 10**-7
alpha_element = alpha_dict*10**-1

regressor = Regressor(
    eta0=eta0,
    kernel_parameter=kernel_parameter,
    dictionary_th=dictionary_th,
    dict_size=dict_size,
    alpha_dict=alpha_dict,
    alpha_element=alpha_element
)
regressor.fit(x, y)
plot_result(regressor)
# Out:
#  99% (4997 of 5000) |#################### | Elapsed Time: 0:01:09 ETA:  0:00:00
